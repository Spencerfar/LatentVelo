# %%
import scib
import latentvelo as ltv
import scanpy as sc
import scvelo as scv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Global seed set to 0

# %% [markdown]
# # Read process and plot data

# %%
adata = sc.read('../synthetic_datasets/bifurcation_2batches.h5ad')

# %%
ltv.utils.anvi_clean_recipe(adata, spliced_key='counts_spliced', unspliced_key='counts_unspliced',
                                 batch_key = 'batch', umap=True, celltype_key='milestone')
# Out:
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# computing neighbors
#     finished (0:00:09) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
scv.pl.umap(adata, color=['batch', 'milestone', 'sim_time'], frameon='artist', legend_loc='right', ncols=2)

# %% [markdown]
# # Train VAE model for batch correction

# %%
model = ltv.models.VAE(observed=85, latent_dim=20, zr_dim=1,
                              batch_correction=True, batches=2)

# %%
epochs, val_ae, val_traj = ltv.train(model, adata, batch_size = 100,
                                      epochs=50, name='batch_correction_bifurcation_params')
# Out:
# Warning, folder already exists. This may overwrite a previous fit.
# 44 velocity genes used
# epoch 0, full loss 187.473, val loss 77.416, recon MSE 0.445, traj MSE 0.404, corr reg -1.491
# epoch 1, full loss 92.869, val loss 48.683, recon MSE 0.366, traj MSE 0.255, corr reg -1.395
# epoch 2, full loss 76.510, val loss 29.067, recon MSE 0.287, traj MSE 0.242, corr reg -1.573
# epoch 3, full loss 57.697, val loss 10.933, recon MSE 0.260, traj MSE 0.228, corr reg -1.751
# epoch 4, full loss 40.891, val loss -4.010, recon MSE 0.235, traj MSE 0.228, corr reg -2.483
# epoch 5, full loss 25.396, val loss -17.142, recon MSE 0.206, traj MSE 0.207, corr reg -2.734
# epoch 6, full loss 13.806, val loss -28.814, recon MSE 0.190, traj MSE 0.189, corr reg -2.879
# epoch 7, full loss 3.528, val loss -38.040, recon MSE 0.173, traj MSE 0.173, corr reg -3.118
# epoch 8, full loss -5.014, val loss -45.731, recon MSE 0.166, traj MSE 0.171, corr reg -3.084
# epoch 9, full loss -12.885, val loss -51.510, recon MSE 0.159, traj MSE 0.164, corr reg -3.055
# epoch 10, full loss -19.236, val loss -57.257, recon MSE 0.149, traj MSE 0.158, corr reg -3.100
# epoch 11, full loss -24.113, val loss -61.555, recon MSE 0.146, traj MSE 0.147, corr reg -2.254
# epoch 12, full loss -30.860, val loss -65.256, recon MSE 0.132, traj MSE 0.144, corr reg -2.429
# epoch 13, full loss -34.083, val loss -67.512, recon MSE 0.132, traj MSE 0.147, corr reg -2.757
# epoch 14, full loss -38.459, val loss -69.791, recon MSE 0.123, traj MSE 0.141, corr reg -2.427
# epoch 15, full loss -41.647, val loss -71.085, recon MSE 0.119, traj MSE 0.137, corr reg -2.653
# epoch 16, full loss -45.372, val loss -72.122, recon MSE 0.117, traj MSE 0.139, corr reg -2.695
# epoch 17, full loss -48.274, val loss -73.015, recon MSE 0.114, traj MSE 0.137, corr reg -2.555
# epoch 18, full loss -50.139, val loss -73.069, recon MSE 0.110, traj MSE 0.137, corr reg -2.652
# epoch 19, full loss -50.856, val loss -72.494, recon MSE 0.111, traj MSE 0.140, corr reg -2.577
# epoch 20, full loss -53.305, val loss -71.500, recon MSE 0.113, traj MSE 0.139, corr reg -2.592
# epoch 21, full loss -54.113, val loss -71.404, recon MSE 0.113, traj MSE 0.137, corr reg -2.704
# Epoch 00022: reducing learning rate of group 0 to 7.5000e-03.
# epoch 22, full loss -55.182, val loss -70.048, recon MSE 0.108, traj MSE 0.138, corr reg -2.447
# epoch 23, full loss -56.081, val loss -68.463, recon MSE 0.105, traj MSE 0.136, corr reg -2.237
# epoch 24, full loss -55.718, val loss -66.647, recon MSE 0.106, traj MSE 0.139, corr reg -2.374
# epoch 25, full loss -56.173, val loss -64.420, recon MSE 0.104, traj MSE 0.137, corr reg -2.144
# epoch 26, full loss -55.578, val loss -64.808, recon MSE 0.105, traj MSE 0.139, corr reg -2.038
# epoch 27, full loss -56.368, val loss -64.848, recon MSE 0.102, traj MSE 0.138, corr reg -2.027
# epoch 28, full loss -56.411, val loss -65.587, recon MSE 0.100, traj MSE 0.137, corr reg -1.939
# epoch 29, full loss -56.290, val loss -66.636, recon MSE 0.099, traj MSE 0.136, corr reg -1.983
# Epoch 00030: reducing learning rate of group 0 to 5.6250e-03.
# epoch 30, full loss -56.223, val loss -66.152, recon MSE 0.099, traj MSE 0.136, corr reg -1.875
# epoch 31, full loss -56.414, val loss -67.926, recon MSE 0.096, traj MSE 0.136, corr reg -2.023
# epoch 32, full loss -54.655, val loss -68.334, recon MSE 0.096, traj MSE 0.138, corr reg -1.909
# epoch 33, full loss -54.983, val loss -68.544, recon MSE 0.096, traj MSE 0.138, corr reg -2.002
# epoch 34, full loss -54.704, val loss -68.530, recon MSE 0.094, traj MSE 0.138, corr reg -1.850
# epoch 35, full loss -53.353, val loss -69.283, recon MSE 0.093, traj MSE 0.138, corr reg -1.840
# Epoch 00036: reducing learning rate of group 0 to 4.2188e-03.
# epoch 36, full loss -53.676, val loss -69.711, recon MSE 0.091, traj MSE 0.136, corr reg -1.990
# epoch 37, full loss -52.693, val loss -70.867, recon MSE 0.092, traj MSE 0.137, corr reg -1.918
# epoch 38, full loss -52.706, val loss -70.469, recon MSE 0.089, traj MSE 0.137, corr reg -1.866
# epoch 39, full loss -52.238, val loss -70.983, recon MSE 0.089, traj MSE 0.136, corr reg -2.023
# epoch 40, full loss -52.081, val loss -70.939, recon MSE 0.089, traj MSE 0.138, corr reg -1.849
# epoch 41, full loss -51.842, val loss -70.867, recon MSE 0.088, traj MSE 0.136, corr reg -2.104
# epoch 42, full loss -50.768, val loss -71.976, recon MSE 0.087, traj MSE 0.136, corr reg -1.926
# Epoch 00043: reducing learning rate of group 0 to 3.1641e-03.
# epoch 43, full loss -50.837, val loss -72.048, recon MSE 0.086, traj MSE 0.135, corr reg -1.931
# epoch 44, full loss -49.361, val loss -71.887, recon MSE 0.086, traj MSE 0.136, corr reg -1.960
# epoch 45, full loss -49.679, val loss -71.709, recon MSE 0.085, traj MSE 0.135, corr reg -1.846
# epoch 46, full loss -48.444, val loss -72.141, recon MSE 0.085, traj MSE 0.136, corr reg -1.890
# epoch 47, full loss -48.487, val loss -72.928, recon MSE 0.085, traj MSE 0.136, corr reg -1.913
# epoch 48, full loss -47.371, val loss -72.276, recon MSE 0.084, traj MSE 0.136, corr reg -1.845
# Epoch 00049: reducing learning rate of group 0 to 2.3730e-03.
# epoch 49, full loss -47.381, val loss -73.042, recon MSE 0.083, traj MSE 0.136, corr reg -1.870
# Loading best model at 49 epochs.

# %%
ltv.plot_history(epochs, val_ae, val_traj)
plt.show()

# %% [markdown]
# # Train annotated VAE model for batch correction

# %%
annot_model = ltv.models.AnnotVAE(observed=85, latent_dim=20, zr_dim=1,
                              batch_correction=True, batches=2, celltypes=len(adata.obs.milestone.unique()))

# %%
epochs, val_ae, val_traj = ltv.train_anvi(annot_model, adata, batch_size = 100, shuffle=False,
                                      epochs=50, name='batch_correction_bifurcation_annot_params')
# Out:
# Warning, folder already exists. This may overwrite a previous fit.
# 44 velocity genes used
# epoch 0, full loss 262.489, val loss 73.983, ae MSE 0.397, traj MSE 0.357, corr reg -1.297
# epoch 1, full loss 77.654, val loss 48.814, ae MSE 0.299, traj MSE 0.233, corr reg -2.271
# epoch 2, full loss 28.544, val loss 27.014, ae MSE 0.258, traj MSE 0.221, corr reg -2.060
# epoch 3, full loss 6.346, val loss 8.105, ae MSE 0.254, traj MSE 0.219, corr reg -2.320
# epoch 4, full loss -9.073, val loss -7.781, ae MSE 0.232, traj MSE 0.213, corr reg -2.433
# epoch 5, full loss -20.307, val loss -21.190, ae MSE 0.219, traj MSE 0.204, corr reg -2.534
# epoch 6, full loss -32.009, val loss -33.046, ae MSE 0.208, traj MSE 0.199, corr reg -2.347
# epoch 7, full loss -43.442, val loss -43.686, ae MSE 0.192, traj MSE 0.174, corr reg -2.427
# epoch 8, full loss -52.294, val loss -53.443, ae MSE 0.203, traj MSE 0.189, corr reg -2.639
# epoch 9, full loss -64.062, val loss -63.093, ae MSE 0.174, traj MSE 0.160, corr reg -2.335
# epoch 10, full loss -70.383, val loss -71.349, ae MSE 0.180, traj MSE 0.168, corr reg -2.305
# epoch 11, full loss -75.551, val loss -79.229, ae MSE 0.180, traj MSE 0.170, corr reg -1.975
# epoch 12, full loss -86.096, val loss -85.717, ae MSE 0.171, traj MSE 0.160, corr reg -2.036
# epoch 13, full loss -93.115, val loss -92.235, ae MSE 0.164, traj MSE 0.156, corr reg -2.275
# epoch 14, full loss -99.293, val loss -97.961, ae MSE 0.161, traj MSE 0.152, corr reg -1.936
# epoch 15, full loss -105.378, val loss -104.046, ae MSE 0.151, traj MSE 0.141, corr reg -1.801
# epoch 16, full loss -110.781, val loss -110.554, ae MSE 0.141, traj MSE 0.135, corr reg -1.856
# epoch 17, full loss -114.116, val loss -115.164, ae MSE 0.148, traj MSE 0.133, corr reg -1.597
# epoch 18, full loss -117.799, val loss -119.705, ae MSE 0.140, traj MSE 0.130, corr reg -1.614
# epoch 19, full loss -119.324, val loss -122.595, ae MSE 0.138, traj MSE 0.129, corr reg -1.605
# epoch 20, full loss -124.484, val loss -125.682, ae MSE 0.134, traj MSE 0.127, corr reg -1.965
# epoch 21, full loss -133.090, val loss -130.090, ae MSE 0.130, traj MSE 0.122, corr reg -1.737
# epoch 22, full loss -133.617, val loss -133.847, ae MSE 0.131, traj MSE 0.126, corr reg -1.953
# epoch 23, full loss -137.671, val loss -136.543, ae MSE 0.129, traj MSE 0.121, corr reg -2.057
# epoch 24, full loss -139.989, val loss -140.123, ae MSE 0.128, traj MSE 0.119, corr reg -2.153
# epoch 25, full loss -145.574, val loss -142.596, ae MSE 0.127, traj MSE 0.118, corr reg -2.292
# epoch 26, full loss -147.285, val loss -145.907, ae MSE 0.126, traj MSE 0.121, corr reg -2.175
# epoch 27, full loss -148.639, val loss -149.446, ae MSE 0.126, traj MSE 0.126, corr reg -2.442
# epoch 28, full loss -149.503, val loss -151.474, ae MSE 0.124, traj MSE 0.119, corr reg -2.437
# epoch 29, full loss -157.074, val loss -153.213, ae MSE 0.118, traj MSE 0.114, corr reg -2.336
# epoch 30, full loss -156.671, val loss -155.469, ae MSE 0.118, traj MSE 0.117, corr reg -2.478
# epoch 31, full loss -155.289, val loss -156.349, ae MSE 0.123, traj MSE 0.124, corr reg -2.439
# epoch 32, full loss -158.730, val loss -158.249, ae MSE 0.118, traj MSE 0.114, corr reg -2.447
# epoch 33, full loss -161.658, val loss -158.678, ae MSE 0.117, traj MSE 0.114, corr reg -2.641
# epoch 34, full loss -163.553, val loss -162.581, ae MSE 0.114, traj MSE 0.115, corr reg -2.683
# epoch 35, full loss -165.602, val loss -162.967, ae MSE 0.113, traj MSE 0.109, corr reg -2.709
# Epoch 00036: reducing learning rate of group 0 to 7.5000e-03.
# epoch 36, full loss -169.026, val loss -167.971, ae MSE 0.112, traj MSE 0.107, corr reg -2.756
# epoch 37, full loss -169.644, val loss -170.404, ae MSE 0.111, traj MSE 0.107, corr reg -2.756
# epoch 38, full loss -171.242, val loss -172.581, ae MSE 0.108, traj MSE 0.105, corr reg -2.877
# epoch 39, full loss -174.253, val loss -173.484, ae MSE 0.108, traj MSE 0.104, corr reg -2.876
# epoch 40, full loss -176.611, val loss -174.577, ae MSE 0.107, traj MSE 0.103, corr reg -2.757
# epoch 41, full loss -178.309, val loss -176.491, ae MSE 0.106, traj MSE 0.101, corr reg -2.831
# epoch 42, full loss -177.759, val loss -177.164, ae MSE 0.108, traj MSE 0.104, corr reg -2.717
# epoch 43, full loss -182.631, val loss -179.119, ae MSE 0.105, traj MSE 0.100, corr reg -2.788
# epoch 44, full loss -179.952, val loss -179.363, ae MSE 0.105, traj MSE 0.100, corr reg -2.755
# epoch 45, full loss -181.489, val loss -181.720, ae MSE 0.104, traj MSE 0.101, corr reg -2.848
# epoch 46, full loss -184.977, val loss -182.956, ae MSE 0.103, traj MSE 0.097, corr reg -2.845
# epoch 47, full loss -183.047, val loss -183.015, ae MSE 0.102, traj MSE 0.097, corr reg -2.837
# Epoch 00048: reducing learning rate of group 0 to 5.6250e-03.
# epoch 48, full loss -186.733, val loss -185.997, ae MSE 0.100, traj MSE 0.096, corr reg -2.852
# epoch 49, full loss -188.613, val loss -188.626, ae MSE 0.099, traj MSE 0.095, corr reg -2.783
# Loading best model at 49 epochs.

# %%
ltv.plot_history(epochs, val_ae, val_traj)
plt.show()

# %% [markdown]
# # Get outputs for both models

# %%
latent_adata = ltv.output_results(model, adata)

# %%
annot_latent_adata = ltv.output_results(annot_model, adata, annot=True)

# %%
scv.tl.velocity_graph(latent_adata, vkey='spliced_velocity')
scv.tl.velocity_graph(annot_latent_adata, vkey='spliced_velocity')
# Out:
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'spliced_velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'spliced_velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %% [markdown]
# # Plot VAE model on original unintegrated space

# %%
scv.pl.velocity_embedding_stream(latent_adata, vkey='spliced_velocity', 
                                 color=['batch', 'sim_time', 'latent_time']
                                , legend_loc='right', legend_fontsize=18)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# # Plot annotated VAE model on original unintegrated space

# %%
scv.pl.velocity_embedding_stream(annot_latent_adata, vkey='spliced_velocity', 
                                 color=['batch', 'sim_time', 'latent_time']
                                , legend_loc='right', legend_fontsize=18)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# # Plot VAE model on integrated latent space

# %%
latent_adata.obs['zr'] = latent_adata.obsm['zr'][:,0]
scv.pp.neighbors(latent_adata, use_rep='X', n_neighbors=30)
scv.tl.umap(latent_adata)
scv.tl.velocity_graph(latent_adata, vkey='spliced_velocity')
scv.pl.velocity_embedding_stream(latent_adata, vkey='spliced_velocity', 
                                 color=['batch', 'sim_time', 'latent_time', 'zr'], legend_loc='right',
                                legend_fontsize=18, fontsize=18, color_map='coolwarm')
# Out:
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'spliced_velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# # Plot annotated VAE model on integrated space

# %%
annot_latent_adata.obs['zr'] = annot_latent_adata.obsm['zr'][:,0]
scv.pp.neighbors(annot_latent_adata, use_rep='X', n_neighbors=30)
scv.tl.umap(annot_latent_adata)
scv.tl.velocity_graph(annot_latent_adata, vkey='spliced_velocity')
scv.pl.velocity_embedding_stream(annot_latent_adata, vkey='spliced_velocity', 
                                 color=['batch', 'sim_time', 'latent_time', 'zr'], legend_loc='right',
                                legend_fontsize=18, fontsize=18, color_map='coolwarm')
# Out:
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'spliced_velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# # Compute gene-expression batch correction metrics

# %%
latent_adata.obsm['X_latent'] = latent_adata.X.copy()
ge_metrics = ltv.ev.integration_metrics(latent_adata, label_key='milestone', 
                                         batch_key = 'batch', emb_key='X_latent')

annot_latent_adata.obsm['X_latent'] = annot_latent_adata.X.copy()
annot_ge_metrics = ltv.ev.integration_metrics(annot_latent_adata, label_key='milestone', 
                                         batch_key = 'batch', emb_key='X_latent')
# Out:
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7

# %%
ltv.pl.integration_metrics([ge_metrics, annot_ge_metrics],
                           ['LatentVelo', 'LatentVelo+annot'],
                           edgecolor='#474747ff',height=5, aspect=1) # add annot
plt.show()

# %% [markdown]
# # Compute velocity batch correction metrics

# %%
cluster_edges = [('A', 'B'), ('A', 'C'),
                 ('C', 'E'), ('B', 'D')]

adata.layers['rna_velocity'] = adata.layers['rna_velocity'].todense()
adata.layers['gene_velocity'] = adata.layers['rna_velocity'].copy()
ltv.ev.format_benchmark_adata(adata, latent_adata, estimated_vkey='spliced_velocity')
vae_df = ltv.ev.benchmark_synthetic(adata, basis_list = ['latent'], batch_key='batch', 
                                               cluster_key='milestone', cluster_edges = cluster_edges)


ltv.ev.format_benchmark_adata(adata, annot_latent_adata, estimated_vkey='spliced_velocity')
annot_vae_df = ltv.ev.benchmark_synthetic(adata, basis_list = ['latent'], batch_key='batch', 
                                               cluster_key='milestone', cluster_edges = cluster_edges)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_20', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_10', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_3', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'rna_velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_latent', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_20', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_10', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_3', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_umap', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_20', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_10', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_pca_3', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'spliced_velocity_umap', embedded velocity vectors (adata.obsm)
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/2000 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'rna_velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_latent', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_20', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_10', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_pca_3', embedded velocity vectors (adata.obsm)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'rna_velocity_umap', embedded velocity vectors (adata.obsm)

# %%
import seaborn as sns
ltv.pl.integration_velocity_metrics([vae_df, annot_vae_df],
                                     ['LatentVelo', 'LatentVelo+annot'],
                                     ['latent', 'latent'], figsize=(10,6), 
                                     palette=np.array(sns.color_palette("Set1").as_hex()),
                                    orient='v')
plt.show()
